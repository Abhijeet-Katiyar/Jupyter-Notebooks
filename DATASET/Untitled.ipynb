# %%
import pandas as pd

# %%
df = pd.read_csv("New_York.dat")

# %%
df.head()
# Out:
#   PLACE\tTOT_POP\tPCT_U18\tPC_18_65\tPCT_O65\tMALE_FEM
# 0  Adams village                                 ...
# 1  Adams Center CDP                              ...
# 2  Addison village                               ...
# 3  Airmont CDP                                   ...
# 4  Akron village                                 ...

# %%
Data=pd.DataFrame(df)

# %%
Data.head()
# Out:
#   PLACE\tTOT_POP\tPCT_U18\tPC_18_65\tPCT_O65\tMALE_FEM
# 0  Adams village                                 ...
# 1  Adams Center CDP                              ...
# 2  Addison village                               ...
# 3  Airmont CDP                                   ...
# 4  Akron village                                 ...

# %%
Data.columns
# Out:
# Index(['PLACE\tTOT_POP\tPCT_U18\tPC_18_65\tPCT_O65\tMALE_FEM'], dtype='object')

# %%
import numpy as np

# %%
data = np.genfromtxt("New_York.dat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f3b8181fff8d> in <module>()
# ----> 1 data = np.genfromtxt("New_York.dat")
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2012             # Raise an exception ?
#    2013             if invalid_raise:
# -> 2014                 raise ValueError(errmsg)
#    2015             # Issue a warning ?
#    2016             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 7 columns instead of 6)
#     Line #3 (got 8 columns instead of 6)
#     Line #4 (got 7 columns instead of 6)
#     Line #5 (got 7 columns instead of 6)
# ...

# %%
dat = np.loadtxt("New_York.dat",dtype='str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-a5be032b15b7> in <module>()
# ----> 1 dat = np.loadtxt("New_York.dat",dtype='str')
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1090         # converting the data
#    1091         X = None
# -> 1092         for x in read_data(_loadtxt_chunksize):
#    1093             if X is None:
#    1094                 X = np.array(x, dtype)
#
# C:\Anaconda\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#    1014                 line_num = i + skiprows + 1
#    1015                 raise ValueError("Wrong number of columns at line %d"
# -> 1016                                  % line_num)
#    1017
#    1018             # Convert each value according to its column and store
#
# ...
